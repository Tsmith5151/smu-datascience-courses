# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

#enter file name here:

fname = 'data/train.csv'
df = pd.read_csv(fname,header=0)

# %% [markdown]
# ## Boxplot

# %%
def boxplot(df,x):
    plt.figure(figsize=(15,6))
    g = sns.boxplot(x=x,y='SalePrice',data=df)
    plt.xticks(rotation=45)
    plt.title("Box Plot",fontsize=20)

# %% [markdown]
# ## MS_Subclass

# %%
boxplot(df1,x='MSSubClass')

# %% [markdown]
# ## Neighborhood

# %%
boxplot(df1,x='Neighborhood')

# %% [markdown]
# ## YrSold

# %%
boxplot(df1,x='YrSold')

# %% [markdown]
# ## SaleCondition

# %%
boxplot(df1,x='SaleCondition')

# %% [markdown]
# ## Year Built

# %%
dates = (df['YearBuilt'] > 1870) & (df['YearBuilt'] <= 1920)
df1 = df.loc[dates]
boxplot(df1,x='YearBuilt')

# %%
dates = (df['YearBuilt'] > 1920) & (df['YearBuilt'] <= 1950)
df1 = df.loc[dates]
boxplot(df1,x='YearBuilt')

# %%
dates = (df['YearBuilt'] > 1950) & (df['YearBuilt'] <= 1980)
df1 = df.loc[dates]
boxplot(df1,x='YearBuilt')

# %%
dates = (df['YearBuilt'] > 1980) & (df['YearBuilt'] <= 2010)
df1 = df.loc[dates]
boxplot(df1,x='YearBuilt')
